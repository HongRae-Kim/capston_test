# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler

directory1 = "/Users/hongrae/Downloads/Hallym_project/apg 파일"
data = []

# for i in range(5):
#     min_data = i * 200  # 0, 200, 400, 600, 800
#     max_data = min_data + 200  # 200, 400, 600, 800, 1000
for root, dirs, files in os.walk(directory1):
#     files.sort()
    for file in files:
        if file.endswith(".csv"):
            full_path = os.path.join(root, file)
            df = pd.read_csv(full_path, usecols=['APG Wave'])
            series = df.values.flatten()[:200]  # max data
            series = series.reshape(-1, 1)  # 1D -> 2D
            scaler = MinMaxScaler()
            series = scaler.fit_transform(series)
            data.append(series)

data_array = np.array(data)

# y를 적절하게 수정 필요 (클래스 불균형 고려)

print("Shape of data_array:", data_array.shape)
# Out:
# Shape of data_array: (130, 200, 1)

# %%
import pandas as pd

# 엑셀 파일 불러오기 (엑셀 파일의 경로를 넣어야 합니다)
# df = pd.read_csv("2024-10-11 (11-00-32)-APG【 이기장 】.csv")
df = pd.read_csv("/Users/hongrae/Downloads/Hallym_project/hallym_2GiJang/2024-10-11 (11-00-32)-APG【 이기장 】_3 (1).csv")
df_sorted = df.sort_values(by='TestDate')

# 정렬된 데이터프레임을 확인
# VasType 열의 모든 값에 3을 곱하기
df_sorted['VasType'] = df_sorted['VasType'] * 3
pd.set_option('display.max_rows', None)
# 결과 확인
import pandas as pd

# 조건에 따른 VasType 값 조정 함수 정의
def adjust_vastype(row):
    if row['TypeLebel'] == '+++':
        return row['VasType'] - 3
    elif row['TypeLebel'] == '++':
        return row['VasType'] - 2
    elif row['TypeLebel'] == '+':
        return row['VasType'] - 1
    else:
        return row['VasType']  # 조건에 맞지 않으면 변경하지 않음

# apply 함수로 각 행에 대해 VasType 값을 조정
df_sorted['VasType'] = df_sorted.apply(adjust_vastype, axis=1)

# 결과 확인
pd.set_option('display.max_rows', None)
df_sorted['VasType'].reset_index(drop=True,inplace=True)
df_sorted['VasType'].value_counts()
y = df_sorted['VasType'].values
# y = np.tile(df_sorted['VasType'].values, 5)

# %%
X_flipped = np.flip(data_array, axis=0)

def adjust_amplitude(signal, factor=0.05):
    # signal과 동일한 모양의 랜덤 값을 생성하여 진폭 조정
    return signal * (1 + factor * np.random.uniform(-1, 1, signal.shape))

adjusted_signal = adjust_amplitude(data_array, factor=0.05)
adjusted_signal.shape

X_adjusted=np.vstack((data_array, adjusted_signal))

# 반전 데이터와 원본 데이터 결합
X_augmented = np.vstack((data_array, X_flipped))  # X와 반전 데이터를 위아래로 결합
y_augmented = np.concatenate((y, y)) 

print("Shape of data_array:",X_adjusted.shape)
# Out:
# Shape of data_array: (260, 200, 1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv1D, Flatten, BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.layers import Conv1D, Dropout, Flatten, Dense, BatchNormalization, GlobalAveragePooling1D

# %%
smote = SMOTE(random_state=42, k_neighbors=2)
X = X_adjusted.reshape(X_adjusted.shape[0], -1)  # (650, 200 * 1) 형태로 변환

X_res, y_res = smote.fit_resample(X, y_augmented)
print(X_res.shape, y_res.shape)
X_train, X_val, y_train, y_val = train_test_split(X_res, y_res, test_size=0.2, random_state=42)
# Out:
# (564, 200) (564,)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # 첫 번째 GPU만 사용

# %%
from sklearn.model_selection import StratifiedKFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-fold 교차 검증
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 클래스 가중치 계산
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# 교차 검증 반복
fold_val_accuracies = []
for fold, (train_idx, val_idx) in enumerate(kf.split(X_train, y_train), 1):
    print(f"Fold {fold}/{skf.get_n_splits()}")

    # 학습과 검증 데이터 분할
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    # 모델 정의
    model = Sequential([
        Conv1D(32, kernel_size=5, activation='relu', input_shape=(X_train.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.2),
        Conv1D(32, kernel_size=8, activation='relu', kernel_regularizer=regularizers.l2(0.2)),
        BatchNormalization(),
        Dropout(0.1),
        Conv1D(32, kernel_size=10, activation='relu', kernel_regularizer=regularizers.l2(0.3)),
        BatchNormalization(),
        Dropout(0.2),
        Flatten(),
        Dense(32, activation='relu'),
        Dense(18, activation='softmax')
    ])

    # Learning Rate Scheduler
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    # 모델 컴파일
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])

    # 모델 학습
    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        batch_size=4,
        epochs=10,
        class_weight=class_weight_dict,
        callbacks=[lr_scheduler],
        verbose=1
    )

    # 최종 검증 정확도 저장
    val_accuracy = history.history['val_accuracy'][-1]
    fold_val_accuracies.append(val_accuracy)
    print(f"Fold {fold} validation accuracy: {val_accuracy:.2%}")

# 평균 검증 정확도 출력
mean_val_accuracy = np.mean(fold_val_accuracies)
print(f"평균 검증 정확도: {mean_val_accuracy:.2%}")

# 최종 모델 저장 (최고 성능의 모델을 저장)
best_model = model
best_model.save('final_model-3.keras')
print("최종 모델이 'final_model.keras'로 저장되었습니다.")
# Out:
# Fold 1/5
# Epoch 1/10
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3774 - loss: 15.2135 - val_accuracy: 0.1648 - val_loss: 8.5969 - learning_rate: 0.0010
# Epoch 2/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8098 - loss: 5.9052 - val_accuracy: 0.1648 - val_loss: 5.6077 - learning_rate: 0.0010
# Epoch 3/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7859 - loss: 3.2511 - val_accuracy: 0.2527 - val_loss: 3.8750 - learning_rate: 0.0010
# Epoch 4/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9046 - loss: 1.6099 - val_accuracy: 0.1758 - val_loss: 3.6337 - learning_rate: 0.0010
# Epoch 5/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9480 - loss: 0.9668 - val_accuracy: 0.3626 - val_loss: 2.6818 - learning_rate: 0.0010
# Epoch 6/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9238 - loss: 0.7447 - val_accuracy: 0.8571 - val_loss: 1.2211 - learning_rate: 0.0010
# Epoch 7/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9197 - loss: 0.6641 - val_accuracy: 0.7033 - val_loss: 1.2028 - learning_rate: 0.0010
# Epoch 8/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9371 - loss: 0.5009 - val_accuracy: 0.8462 - val_loss: 0.8973 - learning_rate: 0.0010
# Epoch 9/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9642 - loss: 0.3239 - val_accuracy: 0.8462 - val_loss: 0.7753 - learning_rate: 0.0010
# Epoch 10/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9217 - loss: 0.4636 - val_accuracy: 0.9231 - val_loss: 0.9836 - learning_rate: 0.0010
# Fold 1 validation accuracy: 92.31%
# Fold 2/5
# Epoch 1/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3820 - loss: 15.5332 - val_accuracy: 0.2000 - val_loss: 9.0754 - learning_rate: 0.0010
# Epoch 2/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7810 - loss: 6.4094 - val_accuracy: 0.2111 - val_loss: 5.8984 - learning_rate: 0.0010
# Epoch 3/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8308 - loss: 3.0780 - val_accuracy: 0.2000 - val_loss: 4.6584 - learning_rate: 0.0010
# Epoch 4/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8976 - loss: 1.6017 - val_accuracy: 0.3778 - val_loss: 3.3235 - learning_rate: 0.0010
# Epoch 5/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9238 - loss: 1.0028 - val_accuracy: 0.4667 - val_loss: 2.3753 - learning_rate: 0.0010
# Epoch 6/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9323 - loss: 0.7447 - val_accuracy: 0.6111 - val_loss: 1.6330 - learning_rate: 0.0010
# Epoch 7/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9754 - loss: 0.3509 - val_accuracy: 0.6111 - val_loss: 1.6063 - learning_rate: 0.0010
# Epoch 8/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9346 - loss: 0.3769 - val_accuracy: 0.8556 - val_loss: 1.0745 - learning_rate: 0.0010
# Epoch 9/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9538 - loss: 0.3315 - val_accuracy: 0.7667 - val_loss: 1.3855 - learning_rate: 0.0010
# Epoch 10/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9201 - loss: 0.6105 - val_accuracy: 0.8667 - val_loss: 0.9696 - learning_rate: 0.0010
# Fold 2 validation accuracy: 86.67%
# Fold 3/5
# Epoch 1/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4390 - loss: 14.8502 - val_accuracy: 0.1667 - val_loss: 8.1107 - learning_rate: 0.0010
# Epoch 2/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8020 - loss: 5.5935 - val_accuracy: 0.2111 - val_loss: 5.0714 - learning_rate: 0.0010
# Epoch 3/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9113 - loss: 2.4123 - val_accuracy: 0.2333 - val_loss: 3.8138 - learning_rate: 0.0010
# Epoch 4/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9060 - loss: 1.4711 - val_accuracy: 0.2556 - val_loss: 2.9118 - learning_rate: 0.0010
# Epoch 5/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9324 - loss: 0.8445 - val_accuracy: 0.6889 - val_loss: 1.4776 - learning_rate: 0.0010
# Epoch 6/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9408 - loss: 0.6145 - val_accuracy: 0.6111 - val_loss: 1.6482 - learning_rate: 0.0010
# Epoch 7/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9415 - loss: 0.4536 - val_accuracy: 0.7889 - val_loss: 0.9956 - learning_rate: 0.0010
# Epoch 8/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9539 - loss: 0.4074 - val_accuracy: 0.8778 - val_loss: 0.6316 - learning_rate: 0.0010
# Epoch 9/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9851 - loss: 0.2275 - val_accuracy: 0.8778 - val_loss: 0.5424 - learning_rate: 0.0010
# Epoch 10/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9279 - loss: 0.4720 - val_accuracy: 0.8333 - val_loss: 1.6354 - learning_rate: 0.0010
# Fold 3 validation accuracy: 83.33%
# Fold 4/5
# Epoch 1/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2857 - loss: 15.7329 - val_accuracy: 0.1889 - val_loss: 8.5208 - learning_rate: 0.0010
# Epoch 2/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7781 - loss: 5.8453 - val_accuracy: 0.2667 - val_loss: 4.9800 - learning_rate: 0.0010
# Epoch 3/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9079 - loss: 2.5519 - val_accuracy: 0.3333 - val_loss: 3.3185 - learning_rate: 0.0010
# Epoch 4/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9010 - loss: 1.4848 - val_accuracy: 0.2111 - val_loss: 3.2657 - learning_rate: 0.0010
# Epoch 5/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8727 - loss: 1.1024 - val_accuracy: 0.5556 - val_loss: 1.8125 - learning_rate: 0.0010
# Epoch 6/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9004 - loss: 0.7617 - val_accuracy: 0.6444 - val_loss: 1.3524 - learning_rate: 0.0010
# Epoch 7/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9576 - loss: 0.6030 - val_accuracy: 0.7778 - val_loss: 0.9732 - learning_rate: 0.0010
# Epoch 8/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9727 - loss: 0.3796 - val_accuracy: 0.7778 - val_loss: 0.7376 - learning_rate: 0.0010
# Epoch 9/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9703 - loss: 0.2500 - val_accuracy: 0.9111 - val_loss: 0.8141 - learning_rate: 0.0010
# Epoch 10/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9872 - loss: 0.2308 - val_accuracy: 0.9111 - val_loss: 0.9007 - learning_rate: 0.0010
# Fold 4 validation accuracy: 91.11%
# Fold 5/5
# Epoch 1/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3282 - loss: 15.1227 - val_accuracy: 0.1111 - val_loss: 8.6626 - learning_rate: 0.0010
# Epoch 2/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7301 - loss: 5.7543 - val_accuracy: 0.1111 - val_loss: 5.4545 - learning_rate: 0.0010
# Epoch 3/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8749 - loss: 2.5356 - val_accuracy: 0.1111 - val_loss: 4.2955 - learning_rate: 0.0010
# Epoch 4/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8806 - loss: 1.4359 - val_accuracy: 0.1444 - val_loss: 3.8707 - learning_rate: 0.0010
# Epoch 5/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9219 - loss: 0.9204 - val_accuracy: 0.1667 - val_loss: 3.1558 - learning_rate: 0.0010
# Epoch 6/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9349 - loss: 0.7037 - val_accuracy: 0.7333 - val_loss: 1.0381 - learning_rate: 0.0010
# Epoch 7/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9613 - loss: 0.5586 - val_accuracy: 0.5667 - val_loss: 1.1278 - learning_rate: 0.0010
# Epoch 8/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.2097 - val_accuracy: 0.3333 - val_loss: 1.6143 - learning_rate: 0.0010
# Epoch 9/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9953 - loss: 0.1107 - val_accuracy: 0.8000 - val_loss: 0.6542 - learning_rate: 0.0010
# Epoch 10/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9777 - loss: 0.2825 - val_accuracy: 0.9556 - val_loss: 0.5978 - learning_rate: 0.0010
# Fold 5 validation accuracy: 95.56%
# 평균 검증 정확도: 89.79%
# 최종 모델이 'final_model.keras'로 저장되었습니다.

# %%
from sklearn.model_selection import StratifiedKFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-fold 교차 검증
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 클래스 가중치 계산
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# 교차 검증 반복
fold_val_accuracies = []
for fold, (train_idx, val_idx) in enumerate(kf.split(X_train, y_train), 1):
    print(f"Fold {fold}/{skf.get_n_splits()}")

    # 학습과 검증 데이터 분할
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    # 모델 정의
    model = Sequential([
        Conv1D(32, kernel_size=5, activation='relu', input_shape=(X_train.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.2),
        Conv1D(32, kernel_size=8, activation='relu', kernel_regularizer=regularizers.l2(0.2)),
        BatchNormalization(),
        Dropout(0.1),
        Conv1D(32, kernel_size=10, activation='relu', kernel_regularizer=regularizers.l2(0.3)),
        BatchNormalization(),
        Dropout(0.2),
        Flatten(),
        Dense(32, activation='relu'),
        Dense(18, activation='softmax')
    ])

    # Learning Rate Scheduler
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    # 모델 컴파일
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])

    # 모델 학습
    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        batch_size=4,
        epochs=20,
        class_weight=class_weight_dict,
        callbacks=[lr_scheduler],
        verbose=1
    )

    # 최종 검증 정확도 저장
    val_accuracy = history.history['val_accuracy'][-1]
    fold_val_accuracies.append(val_accuracy)
    print(f"Fold {fold} validation accuracy: {val_accuracy:.2%}")

# 평균 검증 정확도 출력
mean_val_accuracy = np.mean(fold_val_accuracies)
print(f"평균 검증 정확도: {mean_val_accuracy:.2%}")

# 최종 모델 저장 (최고 성능의 모델을 저장)
best_model = model
best_model.save('final_model-epoch20.keras')
print("최종 모델이 'final_model.keras'로 저장되었습니다.")

import matplotlib.pyplot as plt
import numpy as np

# Mock data for demonstration purposes (replace these with actual history.history values)
epochs = 50
mock_loss = np.random.uniform(0.2, 1.0, epochs).cumsum() / np.arange(1, epochs + 1)
mock_val_loss = np.random.uniform(0.2, 1.0, epochs).cumsum() / np.arange(1, epochs + 1)
mock_accuracy = np.linspace(0.5, 0.9, epochs) + np.random.uniform(-0.05, 0.05, epochs)
mock_val_accuracy = np.linspace(0.4, 0.8, epochs) + np.random.uniform(-0.05, 0.05, epochs)

# Plot Loss
plt.subplot(2, 1, 1)
plt.plot(range(1, epochs + 1), mock_loss, label='Train Loss')
plt.plot(range(1, epochs + 1), mock_val_loss, label='Validation Loss', linestyle='--')
plt.title('Model Loss and Accuracy')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(2, 1, 2)
plt.plot(range(1, epochs + 1), mock_accuracy, label='Train Accuracy')
plt.plot(range(1, epochs + 1), mock_val_accuracy, label='Validation Accuracy', linestyle='--')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Fold 1/5
# Epoch 1/20
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3872 - loss: 15.6025 - val_accuracy: 0.1538 - val_loss: 8.4180 - learning_rate: 0.0010
# Epoch 2/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7953 - loss: 5.8879 - val_accuracy: 0.3516 - val_loss: 4.9079 - learning_rate: 0.0010
# Epoch 3/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8451 - loss: 3.0148 - val_accuracy: 0.3626 - val_loss: 3.3348 - learning_rate: 0.0010
# Epoch 4/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8913 - loss: 1.6632 - val_accuracy: 0.3736 - val_loss: 2.3638 - learning_rate: 0.0010
# Epoch 5/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9156 - loss: 1.0226 - val_accuracy: 0.5714 - val_loss: 1.6635 - learning_rate: 0.0010
# Epoch 6/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9238 - loss: 0.7326 - val_accuracy: 0.9011 - val_loss: 0.9339 - learning_rate: 0.0010
# Epoch 7/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9329 - loss: 0.5711 - val_accuracy: 0.8571 - val_loss: 0.9696 - learning_rate: 0.0010
# Epoch 8/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9224 - loss: 0.5760 - val_accuracy: 0.8681 - val_loss: 1.1719 - learning_rate: 0.0010
# Epoch 9/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9693 - loss: 0.3719 - val_accuracy: 0.9231 - val_loss: 0.6090 - learning_rate: 0.0010
# Epoch 10/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9525 - loss: 0.2985 - val_accuracy: 0.9451 - val_loss: 0.7106 - learning_rate: 0.0010
# Epoch 11/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9558 - loss: 0.3107 - val_accuracy: 0.8901 - val_loss: 1.7486 - learning_rate: 0.0010
# Epoch 12/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9684 - loss: 0.4073 - val_accuracy: 0.8901 - val_loss: 0.9695 - learning_rate: 0.0010
# Epoch 13/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9531 - loss: 0.3195 - val_accuracy: 0.9121 - val_loss: 1.0646 - learning_rate: 0.0010
# Epoch 14/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.2970 - val_accuracy: 0.8681 - val_loss: 1.6024 - learning_rate: 0.0010
# Epoch 15/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9686 - loss: 0.3626 - val_accuracy: 0.9341 - val_loss: 0.6675 - learning_rate: 5.0000e-04
# Epoch 16/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9862 - loss: 0.1635 - val_accuracy: 0.9121 - val_loss: 0.5993 - learning_rate: 5.0000e-04
# Epoch 17/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9998 - loss: 0.0854 - val_accuracy: 0.8132 - val_loss: 0.7466 - learning_rate: 5.0000e-04
# Epoch 18/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9917 - loss: 0.0986 - val_accuracy: 0.9121 - val_loss: 1.1775 - learning_rate: 5.0000e-04
# Epoch 19/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9761 - loss: 0.2304 - val_accuracy: 0.9011 - val_loss: 1.0627 - learning_rate: 5.0000e-04
# Epoch 20/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9732 - loss: 0.2483 - val_accuracy: 0.9451 - val_loss: 0.6533 - learning_rate: 5.0000e-04
# Fold 1 validation accuracy: 94.51%
# Fold 2/5
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3394 - loss: 15.8256 - val_accuracy: 0.1000 - val_loss: 9.1069 - learning_rate: 0.0010
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7880 - loss: 6.2819 - val_accuracy: 0.1000 - val_loss: 6.2237 - learning_rate: 0.0010
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8713 - loss: 3.2291 - val_accuracy: 0.1000 - val_loss: 4.6531 - learning_rate: 0.0010
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8512 - loss: 2.0431 - val_accuracy: 0.1889 - val_loss: 3.1838 - learning_rate: 0.0010
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9098 - loss: 1.3632 - val_accuracy: 0.4778 - val_loss: 2.1901 - learning_rate: 0.0010
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9663 - loss: 0.6742 - val_accuracy: 0.6556 - val_loss: 1.7347 - learning_rate: 0.0010
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9793 - loss: 0.4036 - val_accuracy: 0.8333 - val_loss: 1.2335 - learning_rate: 0.0010
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9652 - loss: 0.3513 - val_accuracy: 0.8889 - val_loss: 1.2956 - learning_rate: 0.0010
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9788 - loss: 0.3226 - val_accuracy: 0.8556 - val_loss: 1.3402 - learning_rate: 0.0010
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9231 - loss: 0.5701 - val_accuracy: 0.8000 - val_loss: 2.9071 - learning_rate: 0.0010
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9231 - loss: 0.5618 - val_accuracy: 0.8667 - val_loss: 1.6009 - learning_rate: 0.0010
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9668 - loss: 0.2831 - val_accuracy: 0.8556 - val_loss: 2.1797 - learning_rate: 0.0010
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9437 - loss: 0.4676 - val_accuracy: 0.9000 - val_loss: 1.4393 - learning_rate: 5.0000e-04
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.1794 - val_accuracy: 0.8778 - val_loss: 0.9956 - learning_rate: 5.0000e-04
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9717 - loss: 0.1783 - val_accuracy: 0.9000 - val_loss: 0.9371 - learning_rate: 5.0000e-04
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9976 - loss: 0.0709 - val_accuracy: 0.8667 - val_loss: 0.8829 - learning_rate: 5.0000e-04
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0406 - val_accuracy: 0.8556 - val_loss: 0.8300 - learning_rate: 5.0000e-04
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0277 - val_accuracy: 0.8444 - val_loss: 0.8068 - learning_rate: 5.0000e-04
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.8889 - val_loss: 0.7542 - learning_rate: 5.0000e-04
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9222 - val_loss: 0.8277 - learning_rate: 5.0000e-04
# Fold 2 validation accuracy: 92.22%
# Fold 3/5
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3666 - loss: 15.6804 - val_accuracy: 0.2000 - val_loss: 9.0408 - learning_rate: 0.0010
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7857 - loss: 6.2287 - val_accuracy: 0.2111 - val_loss: 5.5037 - learning_rate: 0.0010
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8648 - loss: 2.9770 - val_accuracy: 0.1667 - val_loss: 4.1417 - learning_rate: 0.0010
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8988 - loss: 1.6871 - val_accuracy: 0.2444 - val_loss: 2.7792 - learning_rate: 0.0010
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9326 - loss: 0.9224 - val_accuracy: 0.5889 - val_loss: 1.5913 - learning_rate: 0.0010
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9053 - loss: 0.7282 - val_accuracy: 0.4889 - val_loss: 1.4534 - learning_rate: 0.0010
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9874 - loss: 0.2692 - val_accuracy: 0.7444 - val_loss: 1.0188 - learning_rate: 0.0010
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.3988 - val_accuracy: 0.8222 - val_loss: 0.8118 - learning_rate: 0.0010
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9856 - loss: 0.2363 - val_accuracy: 0.8556 - val_loss: 0.7112 - learning_rate: 0.0010
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9403 - loss: 0.5041 - val_accuracy: 0.7667 - val_loss: 2.2326 - learning_rate: 0.0010
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8995 - loss: 0.5701 - val_accuracy: 0.7667 - val_loss: 3.5749 - learning_rate: 0.0010
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8757 - loss: 0.7401 - val_accuracy: 0.8333 - val_loss: 0.9494 - learning_rate: 0.0010
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9884 - loss: 0.2262 - val_accuracy: 0.6667 - val_loss: 1.0001 - learning_rate: 0.0010
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9939 - loss: 0.0917 - val_accuracy: 0.7889 - val_loss: 0.9348 - learning_rate: 0.0010
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9552 - loss: 0.3424 - val_accuracy: 0.8889 - val_loss: 0.9370 - learning_rate: 5.0000e-04
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.1395 - val_accuracy: 0.9111 - val_loss: 0.5710 - learning_rate: 5.0000e-04
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0645 - val_accuracy: 0.8889 - val_loss: 0.5886 - learning_rate: 5.0000e-04
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0334 - val_accuracy: 0.7667 - val_loss: 0.7821 - learning_rate: 5.0000e-04
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.8111 - val_loss: 0.6304 - learning_rate: 5.0000e-04
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9991 - loss: 0.0309 - val_accuracy: 0.8667 - val_loss: 1.3210 - learning_rate: 5.0000e-04
# Fold 3 validation accuracy: 86.67%
# Fold 4/5
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4233 - loss: 15.2741 - val_accuracy: 0.1556 - val_loss: 8.6927 - learning_rate: 0.0010
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7722 - loss: 6.1152 - val_accuracy: 0.1556 - val_loss: 5.7779 - learning_rate: 0.0010
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8618 - loss: 2.8765 - val_accuracy: 0.1556 - val_loss: 5.0841 - learning_rate: 0.0010
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9312 - loss: 1.4077 - val_accuracy: 0.1556 - val_loss: 4.0040 - learning_rate: 0.0010
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9666 - loss: 0.6904 - val_accuracy: 0.1667 - val_loss: 3.2393 - learning_rate: 0.0010
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9649 - loss: 0.4600 - val_accuracy: 0.5222 - val_loss: 1.5743 - learning_rate: 0.0010
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9495 - loss: 0.3815 - val_accuracy: 0.7333 - val_loss: 1.0132 - learning_rate: 0.0010
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9847 - loss: 0.2300 - val_accuracy: 0.5889 - val_loss: 1.2030 - learning_rate: 0.0010
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9204 - loss: 0.4626 - val_accuracy: 0.7556 - val_loss: 3.2066 - learning_rate: 0.0010
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8941 - loss: 0.6181 - val_accuracy: 0.7556 - val_loss: 0.9304 - learning_rate: 0.0010
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9885 - loss: 0.2025 - val_accuracy: 0.8444 - val_loss: 0.7258 - learning_rate: 0.0010
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9748 - loss: 0.2435 - val_accuracy: 0.8778 - val_loss: 0.7037 - learning_rate: 0.0010
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9496 - loss: 0.3211 - val_accuracy: 0.8889 - val_loss: 0.9206 - learning_rate: 0.0010
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9768 - loss: 0.2485 - val_accuracy: 0.9000 - val_loss: 0.8935 - learning_rate: 0.0010
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9873 - loss: 0.1588 - val_accuracy: 0.8889 - val_loss: 1.3878 - learning_rate: 0.0010
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9726 - loss: 0.2833 - val_accuracy: 0.9222 - val_loss: 0.6541 - learning_rate: 0.0010
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9900 - loss: 0.1675 - val_accuracy: 0.8556 - val_loss: 1.6253 - learning_rate: 0.0010
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9646 - loss: 0.3428 - val_accuracy: 0.8444 - val_loss: 2.3611 - learning_rate: 0.0010
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9618 - loss: 0.3872 - val_accuracy: 0.8889 - val_loss: 0.9171 - learning_rate: 0.0010
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9797 - loss: 0.2976 - val_accuracy: 0.8778 - val_loss: 0.6934 - learning_rate: 0.0010
# Fold 4 validation accuracy: 87.78%
# Fold 5/5
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3918 - loss: 14.9287 - val_accuracy: 0.2000 - val_loss: 8.6298 - learning_rate: 0.0010
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7635 - loss: 6.1190 - val_accuracy: 0.2000 - val_loss: 5.3315 - learning_rate: 0.0010
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8507 - loss: 3.1351 - val_accuracy: 0.3333 - val_loss: 3.6560 - learning_rate: 0.0010
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8657 - loss: 1.9272 - val_accuracy: 0.5556 - val_loss: 2.1340 - learning_rate: 0.0010
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9492 - loss: 0.9467 - val_accuracy: 0.7667 - val_loss: 1.5948 - learning_rate: 0.0010
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9072 - loss: 0.8615 - val_accuracy: 0.8667 - val_loss: 0.8615 - learning_rate: 0.0010
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9630 - loss: 0.4469 - val_accuracy: 0.9333 - val_loss: 0.6091 - learning_rate: 0.0010
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9627 - loss: 0.3873 - val_accuracy: 0.9556 - val_loss: 0.4796 - learning_rate: 0.0010
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.4133 - val_accuracy: 0.9667 - val_loss: 0.6308 - learning_rate: 0.0010
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9548 - loss: 0.3053 - val_accuracy: 0.9000 - val_loss: 0.6917 - learning_rate: 0.0010
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9586 - loss: 0.3469 - val_accuracy: 0.9444 - val_loss: 0.5710 - learning_rate: 0.0010
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9571 - loss: 0.3468 - val_accuracy: 0.9333 - val_loss: 1.2593 - learning_rate: 0.0010
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.4996 - val_accuracy: 0.9333 - val_loss: 1.0417 - learning_rate: 0.0010
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9708 - loss: 0.3927 - val_accuracy: 0.9667 - val_loss: 0.5195 - learning_rate: 5.0000e-04
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9952 - loss: 0.1909 - val_accuracy: 0.9667 - val_loss: 0.4132 - learning_rate: 5.0000e-04
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9998 - loss: 0.1125 - val_accuracy: 0.9667 - val_loss: 0.3561 - learning_rate: 5.0000e-04
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9992 - loss: 0.0734 - val_accuracy: 0.9333 - val_loss: 0.3794 - learning_rate: 5.0000e-04
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0542 - val_accuracy: 0.9667 - val_loss: 0.3265 - learning_rate: 5.0000e-04
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0325 - val_accuracy: 0.9444 - val_loss: 0.3100 - learning_rate: 5.0000e-04
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 0.9444 - val_loss: 0.3107 - learning_rate: 5.0000e-04
# Fold 5 validation accuracy: 94.44%
# 평균 검증 정확도: 91.12%
# 최종 모델이 'final_model.keras'로 저장되었습니다.

# %%
from sklearn.model_selection import StratifiedKFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-fold 교차 검증
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 클래스 가중치 계산
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# 교차 검증 반복
fold_val_accuracies = []
for fold, (train_idx, val_idx) in enumerate(kf.split(X_train, y_train), 1):
    print(f"Fold {fold}/{skf.get_n_splits()}")

    # 학습과 검증 데이터 분할
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    # 모델 정의
    model = Sequential([
        Conv1D(32, kernel_size=5, activation='relu', input_shape=(X_train.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.3),
        Conv1D(32, kernel_size=8, activation='relu', kernel_regularizer=regularizers.l2(0.2)),
        BatchNormalization(),
        Dropout(0.3),
        Conv1D(32, kernel_size=10, activation='relu', kernel_regularizer=regularizers.l2(0.3)),
        BatchNormalization(),
        Dropout(0.3),
        Flatten(),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(18, activation='softmax')
    ])

    # Learning Rate Scheduler
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    # 모델 컴파일
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])

    # 모델 학습
    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        batch_size=6,
        epochs=20,
        class_weight=class_weight_dict,
        callbacks=[lr_scheduler],
        verbose=1
    )

    # 최종 검증 정확도 저장
    val_accuracy = history.history['val_accuracy'][-1]
    fold_val_accuracies.append(val_accuracy)
    print(f"Fold {fold} validation accuracy: {val_accuracy:.2%}")

# 평균 검증 정확도 출력
mean_val_accuracy = np.mean(fold_val_accuracies)
print(f"평균 검증 정확도: {mean_val_accuracy:.2%}")

# 최종 모델 저장 (최고 성능의 모델을 저장)
best_model = model
best_model.save('final_model_epoch_20241117_1.keras')
print("최종 모델이 'final_model_epoch_20241117.keras'로 저장되었습니다.")

import matplotlib.pyplot as plt
import numpy as np

# Mock data for demonstration purposes (replace these with actual history.history values)
epochs = 20
mock_loss = np.random.uniform(0.2, 1.0, epochs).cumsum() / np.arange(1, epochs + 1)
mock_val_loss = np.random.uniform(0.2, 1.0, epochs).cumsum() / np.arange(1, epochs + 1)
mock_accuracy = np.linspace(0.5, 0.9, epochs) + np.random.uniform(-0.05, 0.05, epochs)
mock_val_accuracy = np.linspace(0.4, 0.8, epochs) + np.random.uniform(-0.05, 0.05, epochs)

# Plot Loss
plt.subplot(2, 1, 1)
plt.plot(range(1, epochs + 1), mock_loss, label='Train Loss')
plt.plot(range(1, epochs + 1), mock_val_loss, label='Validation Loss', linestyle='--')
plt.title('Model Loss and Accuracy')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(2, 1, 2)
plt.plot(range(1, epochs + 1), mock_accuracy, label='Train Accuracy')
plt.plot(range(1, epochs + 1), mock_val_accuracy, label='Validation Accuracy', linestyle='--')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Fold 1/5
# Epoch 1/20
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2075 - loss: 16.9947 - val_accuracy: 0.2198 - val_loss: 11.4566 - learning_rate: 0.0010
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7014 - loss: 9.1739 - val_accuracy: 0.2527 - val_loss: 7.5170 - learning_rate: 0.0010
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6754 - loss: 5.7371 - val_accuracy: 0.2418 - val_loss: 5.3179 - learning_rate: 0.0010
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7732 - loss: 3.6557 - val_accuracy: 0.2527 - val_loss: 4.1586 - learning_rate: 0.0010
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8377 - loss: 2.3993 - val_accuracy: 0.2637 - val_loss: 3.3482 - learning_rate: 0.0010
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8582 - loss: 1.5967 - val_accuracy: 0.2527 - val_loss: 3.0708 - learning_rate: 0.0010
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8135 - loss: 1.3867 - val_accuracy: 0.2857 - val_loss: 2.4902 - learning_rate: 0.0010
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8604 - loss: 1.1213 - val_accuracy: 0.4615 - val_loss: 1.8713 - learning_rate: 0.0010
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8916 - loss: 0.7615 - val_accuracy: 0.7363 - val_loss: 1.0911 - learning_rate: 0.0010
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9090 - loss: 0.6704 - val_accuracy: 0.7363 - val_loss: 0.9677 - learning_rate: 0.0010
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8990 - loss: 0.5211 - val_accuracy: 0.8022 - val_loss: 0.8541 - learning_rate: 0.0010
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9277 - loss: 0.4805 - val_accuracy: 0.8462 - val_loss: 0.6484 - learning_rate: 0.0010
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8681 - loss: 0.6441 - val_accuracy: 0.9341 - val_loss: 0.6270 - learning_rate: 0.0010
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9113 - loss: 0.5004 - val_accuracy: 0.9011 - val_loss: 0.6249 - learning_rate: 0.0010
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9226 - loss: 0.4886 - val_accuracy: 0.9341 - val_loss: 0.5245 - learning_rate: 0.0010
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9390 - loss: 0.4923 - val_accuracy: 0.9121 - val_loss: 0.6618 - learning_rate: 0.0010
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9108 - loss: 0.5931 - val_accuracy: 0.9121 - val_loss: 0.6165 - learning_rate: 0.0010
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9672 - loss: 0.3389 - val_accuracy: 0.9451 - val_loss: 0.3793 - learning_rate: 0.0010
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9313 - loss: 0.3237 - val_accuracy: 0.9451 - val_loss: 0.3502 - learning_rate: 0.0010
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9321 - loss: 0.3545 - val_accuracy: 0.9341 - val_loss: 0.4737 - learning_rate: 0.0010
# Fold 1 validation accuracy: 93.41%
# Fold 2/5
# Epoch 1/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2598 - loss: 17.0664 - val_accuracy: 0.1778 - val_loss: 11.6294 - learning_rate: 0.0010
# Epoch 2/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6493 - loss: 9.3735 - val_accuracy: 0.1778 - val_loss: 8.6441 - learning_rate: 0.0010
# Epoch 3/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6904 - loss: 6.0852 - val_accuracy: 0.1444 - val_loss: 6.3265 - learning_rate: 0.0010
# Epoch 4/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7346 - loss: 3.9365 - val_accuracy: 0.1111 - val_loss: 4.8627 - learning_rate: 0.0010
# Epoch 5/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8291 - loss: 2.5629 - val_accuracy: 0.2222 - val_loss: 3.7644 - learning_rate: 0.0010
# Epoch 6/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7953 - loss: 1.9873 - val_accuracy: 0.1556 - val_loss: 3.5875 - learning_rate: 0.0010
# Epoch 7/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8537 - loss: 1.4593 - val_accuracy: 0.2333 - val_loss: 2.5624 - learning_rate: 0.0010
# Epoch 8/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8631 - loss: 1.0713 - val_accuracy: 0.3778 - val_loss: 2.0741 - learning_rate: 0.0010
# Epoch 9/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9083 - loss: 0.8188 - val_accuracy: 0.2889 - val_loss: 2.2585 - learning_rate: 0.0010
# Epoch 10/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8968 - loss: 0.6376 - val_accuracy: 0.4667 - val_loss: 1.5998 - learning_rate: 0.0010
# Epoch 11/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8860 - loss: 0.6277 - val_accuracy: 0.8889 - val_loss: 0.8126 - learning_rate: 0.0010
# Epoch 12/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9251 - loss: 0.5943 - val_accuracy: 0.8667 - val_loss: 0.7993 - learning_rate: 0.0010
# Epoch 13/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8534 - loss: 0.8089 - val_accuracy: 0.8889 - val_loss: 1.3975 - learning_rate: 0.0010
# Epoch 14/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8966 - loss: 0.6352 - val_accuracy: 0.9000 - val_loss: 0.9467 - learning_rate: 0.0010
# Epoch 15/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9368 - loss: 0.4524 - val_accuracy: 0.8222 - val_loss: 0.9259 - learning_rate: 0.0010
# Epoch 16/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8768 - loss: 0.5758 - val_accuracy: 0.9222 - val_loss: 0.7620 - learning_rate: 0.0010
# Epoch 17/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9376 - loss: 0.3769 - val_accuracy: 0.9222 - val_loss: 0.8024 - learning_rate: 0.0010
# Epoch 18/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9396 - loss: 0.3157 - val_accuracy: 0.9000 - val_loss: 0.8756 - learning_rate: 0.0010
# Epoch 19/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9455 - loss: 0.3131 - val_accuracy: 0.8667 - val_loss: 1.2050 - learning_rate: 0.0010
# Epoch 20/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8953 - loss: 0.5553 - val_accuracy: 0.8778 - val_loss: 1.7715 - learning_rate: 0.0010
# Fold 2 validation accuracy: 87.78%
# Fold 3/5
# Epoch 1/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2051 - loss: 17.0211 - val_accuracy: 0.2222 - val_loss: 11.1079 - learning_rate: 0.0010
# Epoch 2/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6927 - loss: 8.7828 - val_accuracy: 0.1556 - val_loss: 7.6894 - learning_rate: 0.0010
# Epoch 3/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6763 - loss: 5.7740 - val_accuracy: 0.1556 - val_loss: 5.9726 - learning_rate: 0.0010
# Epoch 4/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7420 - loss: 3.9016 - val_accuracy: 0.1556 - val_loss: 4.9071 - learning_rate: 0.0010
# Epoch 5/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7716 - loss: 2.6512 - val_accuracy: 0.1556 - val_loss: 4.3576 - learning_rate: 0.0010
# Epoch 6/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8907 - loss: 1.7311 - val_accuracy: 0.1556 - val_loss: 4.0362 - learning_rate: 0.0010
# Epoch 7/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8422 - loss: 1.3433 - val_accuracy: 0.2000 - val_loss: 2.9565 - learning_rate: 0.0010
# Epoch 8/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8505 - loss: 1.0881 - val_accuracy: 0.2444 - val_loss: 2.4568 - learning_rate: 0.0010
# Epoch 9/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8565 - loss: 0.9785 - val_accuracy: 0.5111 - val_loss: 1.7955 - learning_rate: 0.0010
# Epoch 10/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9001 - loss: 0.8379 - val_accuracy: 0.7556 - val_loss: 1.2060 - learning_rate: 0.0010
# Epoch 11/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9002 - loss: 0.7619 - val_accuracy: 0.7778 - val_loss: 1.2158 - learning_rate: 0.0010
# Epoch 12/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8957 - loss: 0.6757 - val_accuracy: 0.8667 - val_loss: 0.8658 - learning_rate: 0.0010
# Epoch 13/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.4625 - val_accuracy: 0.8556 - val_loss: 0.8197 - learning_rate: 0.0010
# Epoch 14/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9247 - loss: 0.4191 - val_accuracy: 0.8556 - val_loss: 0.7811 - learning_rate: 0.0010
# Epoch 15/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9078 - loss: 0.5058 - val_accuracy: 0.8444 - val_loss: 0.8467 - learning_rate: 0.0010
# Epoch 16/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9311 - loss: 0.4645 - val_accuracy: 0.8889 - val_loss: 0.7959 - learning_rate: 0.0010
# Epoch 17/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9037 - loss: 0.4480 - val_accuracy: 0.8778 - val_loss: 0.9414 - learning_rate: 0.0010
# Epoch 18/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9130 - loss: 0.4562 - val_accuracy: 0.8222 - val_loss: 1.0221 - learning_rate: 0.0010
# Epoch 19/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9179 - loss: 0.5471 - val_accuracy: 0.8889 - val_loss: 0.7997 - learning_rate: 0.0010
# Epoch 20/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.4157 - val_accuracy: 0.9000 - val_loss: 0.6230 - learning_rate: 5.0000e-04
# Fold 3 validation accuracy: 90.00%
# Fold 4/5
# Epoch 1/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3079 - loss: 16.8932 - val_accuracy: 0.2111 - val_loss: 11.5340 - learning_rate: 0.0010
# Epoch 2/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5720 - loss: 9.7720 - val_accuracy: 0.2222 - val_loss: 7.9626 - learning_rate: 0.0010
# Epoch 3/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6732 - loss: 6.0573 - val_accuracy: 0.2222 - val_loss: 6.1000 - learning_rate: 0.0010
# Epoch 4/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7377 - loss: 4.2150 - val_accuracy: 0.2444 - val_loss: 4.7094 - learning_rate: 0.0010
# Epoch 5/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7855 - loss: 2.8391 - val_accuracy: 0.3111 - val_loss: 3.6853 - learning_rate: 0.0010
# Epoch 6/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8175 - loss: 2.1250 - val_accuracy: 0.3778 - val_loss: 3.5855 - learning_rate: 0.0010
# Epoch 7/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8547 - loss: 1.6887 - val_accuracy: 0.3667 - val_loss: 3.4450 - learning_rate: 0.0010
# Epoch 8/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7936 - loss: 1.5130 - val_accuracy: 0.4222 - val_loss: 2.5289 - learning_rate: 0.0010
# Epoch 9/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8606 - loss: 1.1286 - val_accuracy: 0.6111 - val_loss: 1.5557 - learning_rate: 0.0010
# Epoch 10/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8736 - loss: 0.9594 - val_accuracy: 0.6556 - val_loss: 1.4834 - learning_rate: 0.0010
# Epoch 11/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9020 - loss: 0.7290 - val_accuracy: 0.7889 - val_loss: 1.0352 - learning_rate: 0.0010
# Epoch 12/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8980 - loss: 0.6274 - val_accuracy: 0.8667 - val_loss: 0.8766 - learning_rate: 0.0010
# Epoch 13/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9201 - loss: 0.5606 - val_accuracy: 0.8111 - val_loss: 0.9991 - learning_rate: 0.0010
# Epoch 14/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8890 - loss: 0.6523 - val_accuracy: 0.9111 - val_loss: 0.9812 - learning_rate: 0.0010
# Epoch 15/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9331 - loss: 0.4942 - val_accuracy: 0.8778 - val_loss: 0.9808 - learning_rate: 0.0010
# Epoch 16/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9042 - loss: 0.5953 - val_accuracy: 0.9111 - val_loss: 1.1365 - learning_rate: 0.0010
# Epoch 17/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9435 - loss: 0.5657 - val_accuracy: 0.9111 - val_loss: 1.0110 - learning_rate: 0.0010
# Epoch 18/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9702 - loss: 0.3744 - val_accuracy: 0.9222 - val_loss: 0.8354 - learning_rate: 5.0000e-04
# Epoch 19/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9093 - loss: 0.4815 - val_accuracy: 0.8889 - val_loss: 0.8454 - learning_rate: 5.0000e-04
# Epoch 20/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9790 - loss: 0.3320 - val_accuracy: 0.8889 - val_loss: 0.7584 - learning_rate: 5.0000e-04
# Fold 4 validation accuracy: 88.89%
# Fold 5/5
# Epoch 1/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2129 - loss: 16.6974 - val_accuracy: 0.1111 - val_loss: 11.1428 - learning_rate: 0.0010
# Epoch 2/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5838 - loss: 8.8611 - val_accuracy: 0.1111 - val_loss: 8.0977 - learning_rate: 0.0010
# Epoch 3/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6725 - loss: 5.5802 - val_accuracy: 0.1111 - val_loss: 6.4118 - learning_rate: 0.0010
# Epoch 4/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7131 - loss: 3.8779 - val_accuracy: 0.1111 - val_loss: 5.4446 - learning_rate: 0.0010
# Epoch 5/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7810 - loss: 2.4416 - val_accuracy: 0.1111 - val_loss: 4.4050 - learning_rate: 0.0010
# Epoch 6/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8428 - loss: 1.7016 - val_accuracy: 0.1111 - val_loss: 3.5781 - learning_rate: 0.0010
# Epoch 7/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8127 - loss: 1.4574 - val_accuracy: 0.2111 - val_loss: 2.9763 - learning_rate: 0.0010
# Epoch 8/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8642 - loss: 1.1564 - val_accuracy: 0.3556 - val_loss: 2.4399 - learning_rate: 0.0010
# Epoch 9/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8910 - loss: 0.8440 - val_accuracy: 0.3778 - val_loss: 2.1082 - learning_rate: 0.0010
# Epoch 10/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8955 - loss: 0.7502 - val_accuracy: 0.9000 - val_loss: 0.9090 - learning_rate: 0.0010
# Epoch 11/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8648 - loss: 0.7448 - val_accuracy: 0.6889 - val_loss: 1.2194 - learning_rate: 0.0010
# Epoch 12/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8933 - loss: 0.6418 - val_accuracy: 0.9333 - val_loss: 0.6303 - learning_rate: 0.0010
# Epoch 13/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8443 - loss: 0.8034 - val_accuracy: 0.9778 - val_loss: 0.7174 - learning_rate: 0.0010
# Epoch 14/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9282 - loss: 0.6377 - val_accuracy: 0.9222 - val_loss: 0.6782 - learning_rate: 0.0010
# Epoch 15/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8779 - loss: 0.6436 - val_accuracy: 0.9333 - val_loss: 0.6505 - learning_rate: 0.0010
# Epoch 16/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9094 - loss: 0.4664 - val_accuracy: 0.9444 - val_loss: 0.5412 - learning_rate: 0.0010
# Epoch 17/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8860 - loss: 0.5313 - val_accuracy: 0.9556 - val_loss: 0.6462 - learning_rate: 0.0010
# Epoch 18/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9039 - loss: 0.5965 - val_accuracy: 0.9778 - val_loss: 0.4965 - learning_rate: 0.0010
# Epoch 19/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9171 - loss: 0.5275 - val_accuracy: 0.9222 - val_loss: 0.5379 - learning_rate: 0.0010
# Epoch 20/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9283 - loss: 0.3561 - val_accuracy: 0.9667 - val_loss: 0.4865 - learning_rate: 0.0010
# Fold 5 validation accuracy: 96.67%
# 평균 검증 정확도: 91.35%
# 최종 모델이 'final_model_epoch_20241117.keras'로 저장되었습니다.

# %%
print(y_val_fold)
print(y_train_fold)
# Out:
# [1 3 5 0 1 0 2 5 3 2 2 5 0 1 1 4 1 3 4 5 4 4 1 4 2 4 5 2 0 4 5 5 5 0 5 0 0
#  3 5 5 0 4 0 5 2 3 0 2 2 4 1 5 0 5 4 4 3 4 3 1 0 1 2 5 4 3 0 0 5 3 1 5 0 5
#  2 1 5 2 4 0 3 0 2 5 0 4 4 1 4 4]
# [0 4 1 4 1 0 2 5 0 1 0 3 4 0 3 4 2 5 4 1 3 3 4 3 1 3 4 5 4 5 1 1 1 1 4 3 2
#  3 5 3 3 5 5 2 1 1 2 4 3 1 2 1 0 5 2 2 5 5 1 5 5 0 1 2 4 5 5 1 0 0 0 2 1 1
#  0 4 2 0 1 3 0 0 4 5 0 1 3 4 3 0 0 1 0 1 2 4 4 5 1 3 3 3 4 2 4 4 1 2 5 2 0
#  2 5 4 0 0 3 1 3 4 0 1 1 5 4 1 4 4 2 4 0 5 1 0 4 5 3 3 2 3 1 1 4 0 0 1 4 0
#  3 1 3 4 3 2 0 0 4 4 2 0 3 1 3 4 2 1 3 4 3 0 4 5 2 3 3 2 2 4 2 1 5 5 0 2 3
#  5 3 0 5 1 2 4 4 1 0 4 5 2 5 2 2 0 0 4 3 1 0 2 4 0 3 1 2 2 1 0 5 5 1 2 2 4
#  3 1 0 3 2 1 4 2 5 2 1 2 5 5 2 5 1 2 4 1 5 3 4 5 4 2 2 3 5 0 4 4 5 5 3 4 0
#  3 3 2 3 2 0 3 2 1 4 4 0 2 2 3 2 1 0 3 1 1 0 5 0 2 2 2 3 2 0 5 1 1 2 0 5 3
#  4 4 5 0 1 0 5 4 3 1 3 4 1 0 0 1 3 2 3 5 1 3 2 4 1 1 5 4 4 2 3 1 1 2 5 0 2
#  5 5 5 5 1 3 4 5 1 4 4 0 4 0 3 2 2 1 1 4 2 4 0 3 3 0 3 0]

# %%
from tensorflow.keras.models import load_model

# 모델 로드
loaded_model = load_model('/Users/hongrae/Downloads/Hallym_project/hallym_2GiJang/final_model-3.keras')

# 모델 요약 보기 (선택 사항)
loaded_model.summary()
# Out:
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_72 (Conv1D)              │ (None, 196, 32)        │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_72          │ (None, 196, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_72 (Dropout)            │ (None, 196, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_73 (Conv1D)              │ (None, 189, 32)        │         8,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_73          │ (None, 189, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_73 (Dropout)            │ (None, 189, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_74 (Conv1D)              │ (None, 180, 32)        │        10,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_74          │ (None, 180, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_74 (Dropout)            │ (None, 180, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_24 (Flatten)            │ (None, 5760)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 32)             │       184,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 18)             │           594 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 611,672 (2.33 MB)
#  Trainable params: 203,826 (796.20 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 407,654 (1.56 MB)

# %% [markdown]
# test data set

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler

# directory1 = "test_apg/"
directory1 = "/Users/hongrae/Downloads/Hallym_project/apg 파일ㅈ"
data = []

# for i in range(5):
#     min_data = i * 200  # 0, 200, 400, 600, 800
#     max_data = min_data + 200  # 200, 400, 600, 800, 1000
for root, dirs, files in os.walk(directory1):
#     files.sort()
    i=0
    for file in files:
        
        if file.endswith(".csv"):
            
            full_path = os.path.join(root, file)
            df = pd.read_csv(full_path, usecols=['APG Wave'])
            series = df.values.flatten()[:200]  # max data
            series = series.reshape(-1, 1)  # 1D -> 2D
            scaler = MinMaxScaler()
            series = scaler.fit_transform(series)
            data.append(series)
            print(file)
            print(i,"\n")
            i+=1


data_array = np.array(data)
# Out:
# 2024-10-10 (16-41-28) [24][원광호][남][26] APG_Wave【 이기장 】.csv
# 0
#
# 2024-10-10 (16-34-47) [23][박준서][남][23] APG_Wave【 이기장 】.csv
# 1
#
# 2024-10-10 (16-42-41) [24][원광호][남][26] APG_Wave【 이기장 】.csv
# 2
#
# 2024-10-08 (16-53-23) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 3
#
# 2024-10-08 (17-20-19) [6][이찬재][남][24] APG_Wave【 이기장 】.csv
# 4
#
# 2024-10-07 (14-11-22) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 5
#
# 2024-10-08 (16-54-00) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 6
#
# 2024-10-08 (14-46-09) [10][박민규][남][24] APG_Wave【 이기장 】.csv
# 7
#
# 2024-10-09 (21-43-39) [18][심예은][여][23] APG_Wave【 이기장 】.csv
# 8
#
# 2024-10-08 (19-46-41) [17][장연수][남][24] APG_Wave【 이기장 】.csv
# 9
#
# 2024-10-04 (15-21-58) [20205140][김승현][남][23] APG_Wave【 이기장 】.csv
# 10
#
# 2024-10-07 (12-14-52) [20205140][김승현][남][23] APG_Wave【 이기장 】.csv
# 11
#
# 2024-10-08 (15-54-55) [12][이민호][남][22] APG_Wave【 이기장 】.csv
# 12
#
# 2024-10-07 (16-08-44) [4][김태일][남][24] APG_Wave【 이기장 】.csv
# 13
#
# 2024-10-08 (14-46-45) [10][박민규][남][24] APG_Wave【 이기장 】.csv
# 14
#
# 2024-10-10 (16-34-19) [23][박준서][남][23] APG_Wave【 이기장 】.csv
# 15
#
# 2024-10-07 (12-17-11) [20205140][김승현][남][23] APG_Wave【 이기장 】.csv
# 16
#
# 2024-10-08 (16-46-42) [13][이상준][남][28] APG_Wave【 이기장 】.csv
# 17
#
# 2024-10-10 (16-06-13) [19][유한빈][남][22] APG_Wave【 이기장 】.csv
# 18
#
# 2024-10-08 (16-51-53) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 19
#
# 2024-10-07 (15-15-33) [1][김홍래][남][25] APG_Wave【 이기장 】.csv
# 20
#
# 2024-10-10 (16-29-35) [22][서휘도][남][23] APG_Wave【 이기장 】.csv
# 21
#
# 2024-10-08 (18-48-47) [15][박진서][여][20] APG_Wave【 이기장 】.csv
# 22
#
# 2024-10-08 (10-09-26) [8][안정우][남][23] APG_Wave【 이기장 】.csv
# 23
#
# 2024-10-10 (16-41-56) [24][원광호][남][26] APG_Wave【 이기장 】.csv
# 24
#
# 2024-10-07 (12-10-28) [20205140][김승현][남][23] APG_Wave【 이기장 】.csv
# 25
#
# 2024-10-10 (16-25-01) [21][문진영][남][23] APG_Wave【 이기장 】.csv
# 26
#
# 2024-10-08 (14-53-52) [11][유현우][남][26] APG_Wave【 이기장 】.csv
# 27
#
# 2024-10-04 (16-03-28) [1][김홍래][남][25] APG_Wave【 이기장 】.csv
# 28
#
# 2024-10-10 (16-32-53) [23][박준서][남][23] APG_Wave【 이기장 】.csv
# 29
#
# 2024-10-07 (14-07-51) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 30
#
# 2024-10-07 (14-12-06) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 31
#
# 2024-10-10 (16-29-12) [22][서휘도][남][23] APG_Wave【 이기장 】.csv
# 32
#
# 2024-10-09 (21-40-04) [18][심예은][여][23] APG_Wave【 이기장 】.csv
# 33
#
# 2024-10-08 (14-31-37) [9][김용준][남][23] APG_Wave【 이기장 】.csv
# 34
#
# 2024-10-07 (15-16-08) [1][김홍래][남][25] APG_Wave【 이기장 】.csv
# 35
#
# 2024-10-07 (14-10-51) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 36
#
# 2024-10-10 (16-28-48) [22][서휘도][남][23] APG_Wave【 이기장 】.csv
# 37
#
# 2024-10-08 (15-54-16) [12][이민호][남][22] APG_Wave【 이기장 】.csv
# 38
#
# 2024-10-09 (21-36-59) [20205140][김승현][남][23] APG_Wave【 이기장 】.csv
# 39
#
# 2024-10-07 (15-17-05) [1][김홍래][남][25] APG_Wave【 이기장 】.csv
# 40
#
# 2024-10-10 (16-33-16) [23][박준서][남][23] APG_Wave【 이기장 】.csv
# 41
#
# 2024-10-08 (14-52-04) [11][유현우][남][26] APG_Wave【 이기장 】.csv
# 42
#
# 2024-10-10 (16-14-11) [20][김해람][남][22] APG_Wave【 이기장 】.csv
# 43
#
# 2024-10-08 (10-11-28) [8][안정우][남][23] APG_Wave【 이기장 】.csv
# 44
#
# 2024-10-08 (19-46-12) [17][장연수][남][24] APG_Wave【 이기장 】.csv
# 45
#
# 2024-10-08 (17-26-11) [5][허정윤][남][24] APG_Wave【 이기장 】.csv
# 46
#
# 2024-10-08 (18-40-28) [15][박진서][여][20] APG_Wave【 이기장 】.csv
# 47
#
# 2024-10-08 (19-43-50) [16][김영우][남][22] APG_Wave【 이기장 】.csv
# 48
#
# 2024-10-08 (17-09-53) [14][양유진][여][22] APG_Wave【 이기장 】.csv
# 49
#
# 2024-10-08 (14-48-05) [10][박민규][남][24] APG_Wave【 이기장 】.csv
# 50
#
# 2024-10-08 (14-30-59) [9][김용준][남][23] APG_Wave【 이기장 】.csv
# 51
#
# 2024-10-10 (16-15-49) [20][김해람][남][22] APG_Wave【 이기장 】.csv
# 52
#
# 2024-10-07 (16-04-51) [4][김태일][남][24] APG_Wave【 이기장 】.csv
# 53
#
# 2024-10-08 (18-40-51) [15][박진서][여][20] APG_Wave【 이기장 】.csv
# 54
#
# 2024-10-10 (16-43-04) [24][원광호][남][26] APG_Wave【 이기장 】.csv
# 55
#
# 2024-10-07 (12-21-42) [2][김민주][여][20] APG_Wave【 이기장 】.csv
# 56
#
# 2024-10-10 (16-25-27) [21][문진영][남][23] APG_Wave【 이기장 】.csv
# 57
#
# 2024-10-10 (16-13-21) [20][김해람][남][22] APG_Wave【 이기장 】.csv
# 58
#
# 2024-10-08 (14-47-36) [10][박민규][남][24] APG_Wave【 이기장 】.csv
# 59
#
# 2024-10-08 (16-50-59) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 60
#
# 2024-10-08 (16-52-48) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 61
#
# 2024-10-08 (17-19-40) [6][이찬재][남][24] APG_Wave【 이기장 】.csv
# 62
#
# 2024-10-08 (19-42-18) [16][김영우][남][22] APG_Wave【 이기장 】.csv
# 63
#
# 2024-10-08 (17-27-04) [5][허정윤][남][24] APG_Wave【 이기장 】.csv
# 64
#
# 2024-10-10 (16-26-23) [21][문진영][남][23] APG_Wave【 이기장 】.csv
# 65
#
# 2024-10-08 (15-52-58) [12][이민호][남][22] APG_Wave【 이기장 】.csv
# 66
#
# 2024-10-08 (17-25-47) [5][허정윤][남][24] APG_Wave【 이기장 】.csv
# 67
#
# 2024-10-10 (16-08-01) [19][유한빈][남][22] APG_Wave【 이기장 】.csv
# 68
#
# 2024-10-08 (19-47-38) [17][장연수][남][24] APG_Wave【 이기장 】.csv
# 69
#
# 2024-10-08 (16-51-26) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 70
#
# 2024-10-08 (17-11-10) [14][양유진][여][22] APG_Wave【 이기장 】.csv
# 71
#
# 2024-10-08 (17-23-12) [6][이찬재][남][24] APG_Wave【 이기장 】.csv
# 72
#
# 2024-10-10 (16-26-59) [21][문진영][남][23] APG_Wave【 이기장 】.csv
# 73
#
# 2024-10-07 (12-23-34) [2][김민주][여][20] APG_Wave【 이기장 】.csv
# 74
#
# 2024-10-10 (16-30-04) [22][서휘도][남][23] APG_Wave【 이기장 】.csv
# 75
#
# 2024-10-08 (16-47-51) [13][이상준][남][28] APG_Wave【 이기장 】.csv
# 76
#
# 2024-10-08 (17-10-24) [14][양유진][여][22] APG_Wave【 이기장 】.csv
# 77
#
# 2024-10-08 (14-53-26) [11][유현우][남][26] APG_Wave【 이기장 】.csv
# 78
#
# 2024-10-10 (16-08-37) [19][유한빈][남][22] APG_Wave【 이기장 】.csv
# 79
#
# 2024-10-07 (12-23-06) [2][김민주][여][20] APG_Wave【 이기장 】.csv
# 80
#
# 2024-10-07 (16-08-08) [4][김태일][남][24] APG_Wave【 이기장 】.csv
# 81
#
# 2024-10-08 (17-27-33) [5][허정윤][남][24] APG_Wave【 이기장 】.csv
# 82
#
# 2024-10-09 (21-39-15) [18][심예은][여][23] APG_Wave【 이기장 】.csv
# 83
#
# 2024-10-07 (14-12-36) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 84
#
# 2024-10-10 (16-13-45) [20][김해람][남][22] APG_Wave【 이기장 】.csv
# 85
#
# 2024-10-08 (17-11-50) [14][양유진][여][22] APG_Wave【 이기장 】.csv
# 86
#
# 2024-10-10 (16-06-48) [19][유한빈][남][22] APG_Wave【 이기장 】.csv
# 87
#
# 2024-10-08 (14-29-48) [9][김용준][남][23] APG_Wave【 이기장 】.csv
# 88
#
# 2024-10-08 (19-43-20) [16][김영우][남][22] APG_Wave【 이기장 】.csv
# 89
#
# 2024-10-10 (16-33-52) [23][박준서][남][23] APG_Wave【 이기장 】.csv
# 90
#
# 2024-10-07 (16-06-13) [4][김태일][남][24] APG_Wave【 이기장 】.csv
# 91
#
# 2024-10-08 (10-11-02) [8][안정우][남][23] APG_Wave【 이기장 】.csv
# 92
#
# 2024-10-08 (16-48-18) [13][이상준][남][28] APG_Wave【 이기장 】.csv
# 93
#
# 2024-10-08 (10-09-57) [8][안정우][남][23] APG_Wave【 이기장 】.csv
# 94
#
# 2024-10-08 (10-05-36) [7][홍진우][남][24] APG_Wave【 이기장 】.csv
# 95
#
# 2024-10-10 (16-14-57) [20][김해람][남][22] APG_Wave【 이기장 】.csv
# 96
#
# 2024-10-08 (15-53-22) [12][이민호][남][22] APG_Wave【 이기장 】.csv
# 97
#
# 2024-10-10 (16-25-52) [21][문진영][남][23] APG_Wave【 이기장 】.csv
# 98
#
# 2024-10-08 (18-42-51) [15][박진서][여][20] APG_Wave【 이기장 】.csv
# 99
#
# 2024-10-08 (14-52-29) [11][유현우][남][26] APG_Wave【 이기장 】.csv
# 100
#
# 2024-10-07 (16-10-49) [5][허정윤][남][24] APG_Wave【 이기장 】.csv
# 101
#
# 2024-10-08 (19-42-51) [16][김영우][남][22] APG_Wave【 이기장 】.csv
# 102
#
# 2024-10-09 (21-37-55) [18][심예은][여][23] APG_Wave【 이기장 】.csv
# 103
#
# 2024-10-09 (21-44-28) [18][심예은][여][23] APG_Wave【 이기장 】.csv
# 104
#
# 2024-10-07 (12-22-41) [2][김민주][여][20] APG_Wave【 이기장 】.csv
# 105
#
# 2024-10-08 (16-47-24) [13][이상준][남][28] APG_Wave【 이기장 】.csv
# 106
#
# 2024-10-08 (10-10-31) [8][안정우][남][23] APG_Wave【 이기장 】.csv
# 107
#
# 2024-10-08 (14-30-24) [9][김용준][남][23] APG_Wave【 이기장 】.csv
# 108
#
# 2024-10-08 (16-49-35) [13][이상준][남][28] APG_Wave【 이기장 】.csv
# 109
#
# 2024-10-08 (17-26-40) [5][허정윤][남][24] APG_Wave【 이기장 】.csv
# 110
#
# 2024-10-08 (19-47-11) [17][장연수][남][24] APG_Wave【 이기장 】.csv
# 111
#
# 2024-10-08 (14-32-35) [9][김용준][남][23] APG_Wave【 이기장 】.csv
# 112
#
# 2024-10-08 (17-12-17) [14][양유진][여][22] APG_Wave【 이기장 】.csv
# 113
#
# 2024-10-07 (15-16-38) [1][김홍래][남][25] APG_Wave【 이기장 】.csv
# 114
#
# 2024-10-08 (14-33-11) [9][김용준][남][23] APG_Wave【 이기장 】.csv
# 115
#
# 2024-10-07 (16-07-44) [4][김태일][남][24] APG_Wave【 이기장 】.csv
# 116
#
# 2024-10-08 (19-45-32) [17][장연수][남][24] APG_Wave【 이기장 】.csv
# 117
#
# 2024-10-08 (18-41-48) [15][박진서][여][20] APG_Wave【 이기장 】.csv
# 118
#
# 2024-10-08 (14-47-11) [10][박민규][남][24] APG_Wave【 이기장 】.csv
# 119
#
# 2024-10-10 (16-28-16) [22][서휘도][남][23] APG_Wave【 이기장 】.csv
# 120
#
# 2024-10-10 (16-07-19) [19][유한빈][남][22] APG_Wave【 이기장 】.csv
# 121
#
# 2024-10-07 (12-15-39) [20205140][김승현][남][23] APG_Wave【 이기장 】.csv
# 122
#
# 2024-10-08 (16-52-20) [3][배준형][남][22] APG_Wave【 이기장 】.csv
# 123
#
# 2024-10-08 (15-52-10) [12][이민호][남][22] APG_Wave【 이기장 】.csv
# 124
#
# 2024-10-10 (16-39-53) [24][원광호][남][26] APG_Wave【 이기장 】.csv
# 125
#
# 2024-10-08 (19-41-44) [16][김영우][남][22] APG_Wave【 이기장 】.csv
# 126
#
# 2024-10-08 (14-53-01) [11][유현우][남][26] APG_Wave【 이기장 】.csv
# 127
#
# 2024-10-07 (12-20-19) [2][김민주][여][20] APG_Wave【 이기장 】.csv
# 128
#
# 2024-10-08 (16-48-49) [13][이상준][남][28] APG_Wave【 이기장 】.csv
# 129

# %%
import numpy as np

# 숫자를 문자열로 변환하여 각 자리수를 리스트로 만듦
number = 544444444443344
labels = [int(digit) for digit in str(number)]

# Numpy 배열로 변환 (필요하면)
labels_array = np.array(labels)

# 결과 출력
print("Labels as list:", labels)
print("Labels as numpy array:", labels_array)
# Out:
# Labels as list: [5, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 3, 4, 4]
# Labels as numpy array: [5 4 4 4 4 4 4 4 4 4 4 3 3 4 4]

# %%
import numpy as np
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix

# 저장된 모델 로드
model = load_model('학습률75.56%.keras')

# 테스트 데이터 로드 (예시)
# X_test와 y_test는 미리 준비되어야 합니다.
X_test= data_array 
y_test = labels_array
# X_test와 y_test를 적절히 전처리한 상태로 준비하세요.

# 모델 테스트
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)

# 테스트 데이터 예측
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

import numpy as np

# 두 배열 요소별 비교 (일치 여부)
comparison = y_pred == y_test

# True의 비율 계산 (정확도 확인)
accuracy = np.mean(comparison)

print("일치 여부 (True/False):", comparison)
print(f"정확도: {accuracy:.2%}")
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 15
#      11 y_test = labels_array
#      12 # X_test와 y_test를 적절히 전처리한 상태로 준비하세요.
#      13
#      14 # 모델 테스트
# ---> 15 test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
#      17 # 테스트 데이터 예측
#      18 y_pred_probs = model.predict(X_test)
#
# File ~/Downloads/Hallym_project/venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Downloads/Hallym_project/venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/data_adapter_utils.py:114, in check_data_cardinality(data)
#     110     sizes = ", ".join(
#     111         str(i.shape[0]) for i in tree.flatten(single_data)
#     112     )
#     113     msg += f"'{label}' sizes: {sizes}\n"
# --> 114 raise ValueError(msg)
#
# ValueError: Data cardinality is ambiguous. Make sure all arrays contain the same number of samples.'x' sizes: 130
# 'y' sizes: 15
