# %% [markdown]
# 전처리 과정
# apg 데이터를 200초 단위까지 끊어서 MinMaxScaler를 이용해 정규화 시켜줌 그 후 con1v 모델의 input 값에 맞게 변형시켜줌

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler

directory1 = "../apg 파일"
data = []

# 데이터 전처리
for root, dirs, files in os.walk(directory1):
    for file in files:
        if file.endswith(".csv"):
            full_path = os.path.join(root, file)
            df = pd.read_csv(full_path, usecols=['APG Wave'])

            # 데이터 길이 고정
            series = df.values.flatten()
            if len(series) < 200:
                series = np.pad(series, (0, 200 - len(series)), mode='constant')
            else:
                series = series[:200]

            # MinMaxScaler 적용
            series = series.reshape(-1, 1)  # (200, 1)
            scaler = MinMaxScaler()
            series = scaler.fit_transform(series)
            data.append(series.flatten())  # (200,) 형태로 저장

# 배열로 변환
data_array = np.array(data)  # (num_files, 200)

print("Shape of data_array:", data_array.shape)  # 예상: (num_files, 200)
# Out:
# Shape of data_array: (130, 200)

# %% [markdown]
# apg데이터의 y_label값을 불러오는 코드입니다.

# %%
import pandas as pd

# 엑셀 파일 불러오기 (엑셀 파일의 경로를 넣어야 합니다)
df = pd.read_csv("./2024-10-11 (11-00-32)-APG【 이기장 】_3 (1).csv")
df_sorted = df.sort_values(by='TestDate')

# 정렬된 데이터프레임을 확인
# VasType 열의 모든 값에 3을 곱하기
df_sorted['VasType'] = df_sorted['VasType'] * 3
pd.set_option('display.max_rows', None)
# 결과 확인
import pandas as pd

# 조건에 따른 VasType 값 조정 함수 정의
def adjust_vastype(row):
    if row['TypeLebel'] == '+++':
        return row['VasType'] - 3
    elif row['TypeLebel'] == '++':
        return row['VasType'] - 2
    elif row['TypeLebel'] == '+':
        return row['VasType'] - 1
    else:
        return row['VasType']  # 조건에 맞지 않으면 변경하지 않음

# apply 함수로 각 행에 대해 VasType 값을 조정
df_sorted['VasType'] = df_sorted.apply(adjust_vastype, axis=1)

# 결과 확인
pd.set_option('display.max_rows', None)
df_sorted['VasType'].reset_index(drop=True,inplace=True)
df_sorted['VasType'].value_counts()
y = df_sorted['VasType'].values
# y = np.tile(df_sorted['VasType'].values, 5)

# %% [markdown]
# ---
#
# # APG 데이터 증강 기법
#
# APG 데이터의 수가 부족하여 **증강 기법**을 이용해 데이터를 늘렸습니다.
#
# ---
#
# ## **증강 조합의 구성**
#
# 1. **노이즈 추가 (Gaussian Noise)**
#    - 다양한 `noise_std` 값으로 여러 데이터를 생성 가능.
#      - 예: `noise_std = [0.01, 0.02, 0.03]` → 3가지 변형
#
# 2. **시간 왜곡 (Time-Warping)**
#    - 시간 축 왜곡 강도(`sigma`)를 다르게 설정하여 데이터 생성 가능.
#      - 예: `sigma = [0.1, 0.2, 0.3]` → 3가지 변형
#
# 3. **진폭 왜곡 (Magnitude-Warping)**
#    - 진폭 변형 강도(`factor`)를 다르게 설정하여 데이터 생성 가능.
#      - 예: `factor = [0.1, 0.2, 0.3]` → 3가지 변형
#
# ---
#
# ## **증강 조합의 계산**
#
# 각 증강 기법은 **독립적으로 적용**될 수 있으며, 동시에 **조합**될 수도 있습니다.
# 조합의 총 개수는 다음과 같이 계산합니다:
#
# \[
# \{총 조합 수} = (\{노이즈 변형 개수}) * (\{시간 왜곡 변형 개수}) * (\{진폭 왜곡 변형 개수})
# \]
#
# ### **예시 계산**
# - 노이즈 변형 개수: **3**
# - 시간 왜곡 변형 개수: **3**
# - 진폭 왜곡 변형 개수: **3**
#
# \[
# 3 (\{노이즈}) * 3 (\{시간 왜곡}) * 3 (\{진폭 왜곡}) = 27 \{ 조합}
# \]
#
# ---
#
# ## **총 생성 가능한 데이터 수**
#
# - **원본 데이터 개수**: 130개
# - **증강 조합 수**: 27개
#
# \[
# \{총 데이터 수} = 130 (\{원본 데이터}) * 27 (\{증강 조합}) = 3510 \{ 개}
# \]
#
# ---
#
# ### **요약**
#
# - **원본 데이터 개수**: 130개
# - **총 조합 수**: 27개
# - **증강 후 데이터 총 개수**: **3510개**
#
# ---

# %%
import numpy as np

# 증강 함수 정의
def add_gaussian_noise(data, noise_std):
    noise = np.random.normal(0, noise_std, data.shape)
    return data + noise

def time_warp(data, sigma):
    time_stretch = np.linspace(0, 1, len(data))
    random_noise = np.random.normal(1.0, sigma, len(data))
    warped_time = np.cumsum(random_noise) / np.sum(random_noise)
    interpolated = np.interp(np.linspace(0, 1, len(data)), warped_time, data)
    return interpolated

def magnitude_warp(data, factor):
    magnitude_variation = 1 + np.random.uniform(-factor, factor, size=data.shape)
    return data * magnitude_variation

def augment_data_with_labels(data, labels, noise_levels, time_sigmas, magnitude_factors):
    augmented_data = []
    augmented_labels = []
    for i, sample in enumerate(data):
        label = labels[i]  # 해당 샘플의 라벨
        for noise in noise_levels:
            for sigma in time_sigmas:
                for factor in magnitude_factors:
                    noisy_data = add_gaussian_noise(sample, noise)
                    warped_time_data = time_warp(noisy_data, sigma)
                    warped_magnitude_data = magnitude_warp(warped_time_data, factor)
                    augmented_data.append(warped_magnitude_data)
                    augmented_labels.append(label)  # 라벨은 원본과 동일하게 추가
    return np.array(augmented_data), np.array(augmented_labels)

# 원본 데이터와 라벨
original_data = data_array
original_labels = y

# 증강 설정
noise_levels = [0.01, 0.02, 0.03]
time_sigmas = [0.1, 0.2, 0.3]
magnitude_factors = [0.1, 0.2, 0.3]

# 증강 수행
augmented_data, augmented_labels = augment_data_with_labels(
    original_data, original_labels, noise_levels, time_sigmas, magnitude_factors
)

# 결과 확인
print(f"원본 데이터 개수: {len(original_data)}")
print(f"증강된 데이터 개수: {len(augmented_data)}")
print(f"증강된 라벨 개수: {len(augmented_labels)}")

# 샘플 출력
print("증강된 데이터 샘플:", augmented_data[0])
print("증강된 데이터 라벨:", augmented_labels[0])
# Out:
# 원본 데이터 개수: 130
# 증강된 데이터 개수: 3510
# 증강된 라벨 개수: 3510
# 증강된 데이터 샘플: [ 0.51801611  0.51314755  0.60806985  0.56113787  0.6549029   0.61990224
#   0.63546059  0.71727425  0.71852379  0.71486052  0.73853675  0.76956015
#   0.70347737  0.66025965  0.66167131  0.52492116  0.47809222  0.51099379
#   0.4397015   0.43692248  0.3790865   0.40989595  0.42290117  0.37898488
#   0.43093677  0.42358947  0.42240765  0.48820775  0.51735137  0.47767847
#   0.56376473  0.54611116  0.57609317  0.5484144   0.62233828  0.55981202
#   0.53379654  0.59384055  0.64266253  0.60032841  0.6136392   0.53071352
#   0.59458895  0.57547368  0.57134601  0.52359078  0.54181741  0.47326148
#   0.52185209  0.53173582  0.46754905  0.56254872  0.5480621   0.48974616
#   0.53885574  0.56829311  0.59634375  0.68532473  0.726534    0.87702722
#   0.88876758  0.97095266  0.97544619  0.83478265  0.74489083  0.6378658
#   0.41401926  0.24665158  0.12666098  0.03520859 -0.00267936  0.01991918
#   0.07668693  0.15406207  0.2736887   0.30250136  0.42697837  0.47198134
#   0.577271    0.58331586  0.63442822  0.63424623  0.57166348  0.71317756
#   0.63302431  0.74303053  0.79516763  0.74594963  0.65365646  0.73186955
#   0.58810707  0.57230587  0.52341616  0.4569367   0.43532551  0.40316283
#   0.35409429  0.42892024  0.38637908  0.43345174  0.43815187  0.46304232
#   0.50742068  0.46783978  0.5209143   0.47961479  0.54937916  0.57291809
#   0.59274478  0.56097582  0.57890503  0.57660289  0.57750952  0.57586139
#   0.60700789  0.50774101  0.61540222  0.54111108  0.55736515  0.62609925
#   0.56743252  0.56547227  0.5749195   0.59698678  0.4786182   0.50944195
#   0.47881153  0.49544938  0.47949298  0.50876282  0.47967072  0.50445329
#   0.49507935  0.53196206  0.58635043  0.59294549  0.71572143  0.70399749
#   0.87261375  0.90217171  0.87026189  1.02371685  0.92719278  0.74580022
#   0.61246895  0.4312583   0.26657521  0.14128734  0.06028581  0.04544088
#   0.07258539  0.14537983  0.21612025  0.32831287  0.4106323   0.45632194
#   0.45735633  0.61380318  0.54496689  0.56657441  0.63344386  0.66348126
#   0.66111626  0.5910064   0.61066765  0.71969003  0.66813552  0.65793322
#   0.60101957  0.63232568  0.5823359   0.49100782  0.46656844  0.40118217
#   0.42525082  0.38108184  0.40214285  0.42689989  0.38446324  0.43531954
#   0.43456817  0.48882996  0.45869931  0.48240614  0.58514947  0.51337028
#   0.59932124  0.56452096  0.6284067   0.52997009  0.6247322   0.57239637
#   0.57935411  0.52091784  0.58261099  0.576405    0.57068717  0.4973623
#   0.54567657  0.52445246]
# 증강된 데이터 라벨: 1

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Flatten, BatchNormalization,Dense, Dropout
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
augmented_data =augmented_data .reshape(augmented_data.shape[0], -1)  # (650, 200 * 1) 형태로 변환

X_train, X_val, y_train, y_val = train_test_split(augmented_data, augmented_labels , test_size=0.2, random_state=42)

# %%
skf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-fold 교차 검증

# 클래스 가중치 계산
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# 교차 검증 반복
fold_val_accuracies = []
for fold, (train_idx, val_idx) in enumerate(kf.split(X_train, y_train), 1):
    print(f"Fold {fold}/{skf.get_n_splits()}")

    # 학습과 검증 데이터 분할
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    # 모델 정의
    model = Sequential([
        Conv1D(32, kernel_size=5, activation='relu', input_shape=(X_train.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.3),
        Conv1D(32, kernel_size=8, activation='relu', kernel_regularizer=regularizers.l2(0.2)),
        BatchNormalization(),
        Dropout(0.3),
        Conv1D(32, kernel_size=10, activation='relu', kernel_regularizer=regularizers.l2(0.3)),
        BatchNormalization(),
        Dropout(0.3),
        Flatten(),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(18, activation='softmax')
    ])

    # Learning Rate Scheduler
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    # 모델 컴파일
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])

    # 모델 학습
    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        batch_size=6,
        epochs=20,
        class_weight=class_weight_dict,
        callbacks=[lr_scheduler],
        verbose=1
    )

    # 최종 검증 정확도 저장
    val_accuracy = history.history['val_accuracy'][-1]
    fold_val_accuracies.append(val_accuracy)
    print(f"Fold {fold} validation accuracy: {val_accuracy:.2%}")

# 평균 검증 정확도 출력
mean_val_accuracy = np.mean(fold_val_accuracies)
print(f"평균 검증 정확도: {mean_val_accuracy:.2%}")

# 최종 모델 저장 (최고 성능의 모델을 저장)
best_model = model
best_model.save('final_model_1120.keras')
print("최종 모델이 'final_model_1120.keras'로 저장되었습니다.")

import matplotlib.pyplot as plt
import numpy as np

# Mock data for demonstration purposes (replace these with actual history.history values)
epochs = 20
mock_loss = np.random.uniform(0.2, 1.0, epochs).cumsum() / np.arange(1, epochs + 1)
mock_val_loss = np.random.uniform(0.2, 1.0, epochs).cumsum() / np.arange(1, epochs + 1)
mock_accuracy = np.linspace(0.5, 0.9, epochs) + np.random.uniform(-0.05, 0.05, epochs)
mock_val_accuracy = np.linspace(0.4, 0.8, epochs) + np.random.uniform(-0.05, 0.05, epochs)

# Plot Loss
plt.subplot(2, 1, 1)
plt.plot(range(1, epochs + 1), mock_loss, label='Train Loss')
plt.plot(range(1, epochs + 1), mock_val_loss, label='Validation Loss', linestyle='--')
plt.title('Model Loss and Accuracy')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(2, 1, 2)
plt.plot(range(1, epochs + 1), mock_accuracy, label='Train Accuracy')
plt.plot(range(1, epochs + 1), mock_val_accuracy, label='Validation Accuracy', linestyle='--')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Fold 1/5
# Epoch 1/20
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2827 - loss: 12.8617 - val_accuracy: 0.3203 - val_loss: 4.0028 - learning_rate: 0.0010
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5460 - loss: 2.7166 - val_accuracy: 0.6868 - val_loss: 1.3640 - learning_rate: 0.0010
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5876 - loss: 1.3915 - val_accuracy: 0.6904 - val_loss: 1.0096 - learning_rate: 0.0010
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6384 - loss: 1.1644 - val_accuracy: 0.6601 - val_loss: 1.5871 - learning_rate: 0.0010
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6388 - loss: 1.0723 - val_accuracy: 0.8149 - val_loss: 0.7410 - learning_rate: 0.0010
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6856 - loss: 1.0294 - val_accuracy: 0.6975 - val_loss: 0.9789 - learning_rate: 0.0010
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6953 - loss: 0.8676 - val_accuracy: 0.7473 - val_loss: 1.1613 - learning_rate: 0.0010
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7126 - loss: 0.8773 - val_accuracy: 0.8060 - val_loss: 0.8748 - learning_rate: 0.0010
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7414 - loss: 0.7942 - val_accuracy: 0.8505 - val_loss: 0.6143 - learning_rate: 0.0010
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7312 - loss: 0.8777 - val_accuracy: 0.7402 - val_loss: 0.9778 - learning_rate: 0.0010
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7288 - loss: 0.7876 - val_accuracy: 0.7829 - val_loss: 1.4009 - learning_rate: 0.0010
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7399 - loss: 0.9581 - val_accuracy: 0.6779 - val_loss: 2.0303 - learning_rate: 0.0010
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7109 - loss: 0.9609 - val_accuracy: 0.5302 - val_loss: 1.3056 - learning_rate: 0.0010
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6991 - loss: 1.0685 - val_accuracy: 0.8399 - val_loss: 0.6837 - learning_rate: 0.0010
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7862 - loss: 0.5894 - val_accuracy: 0.8648 - val_loss: 0.5642 - learning_rate: 5.0000e-04
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8142 - loss: 0.5465 - val_accuracy: 0.8932 - val_loss: 0.4753 - learning_rate: 5.0000e-04
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8346 - loss: 0.4326 - val_accuracy: 0.9181 - val_loss: 0.3492 - learning_rate: 5.0000e-04
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8316 - loss: 0.4262 - val_accuracy: 0.8915 - val_loss: 0.5848 - learning_rate: 5.0000e-04
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8093 - loss: 0.5915 - val_accuracy: 0.8808 - val_loss: 0.5132 - learning_rate: 5.0000e-04
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8279 - loss: 0.4838 - val_accuracy: 0.8843 - val_loss: 0.4817 - learning_rate: 5.0000e-04
# Fold 1 validation accuracy: 88.43%
# Fold 2/5
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2274 - loss: 13.2069 - val_accuracy: 0.1904 - val_loss: 4.2752 - learning_rate: 0.0010
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5836 - loss: 2.7501 - val_accuracy: 0.6317 - val_loss: 1.6905 - learning_rate: 0.0010
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6081 - loss: 1.4741 - val_accuracy: 0.6904 - val_loss: 1.1055 - learning_rate: 0.0010
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6446 - loss: 1.1009 - val_accuracy: 0.6922 - val_loss: 1.1880 - learning_rate: 0.0010
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6637 - loss: 1.0421 - val_accuracy: 0.7847 - val_loss: 0.8715 - learning_rate: 0.0010
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6956 - loss: 0.8822 - val_accuracy: 0.7776 - val_loss: 0.9199 - learning_rate: 0.0010
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7133 - loss: 0.7489 - val_accuracy: 0.8114 - val_loss: 0.7005 - learning_rate: 0.0010
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7393 - loss: 0.7304 - val_accuracy: 0.7972 - val_loss: 0.8847 - learning_rate: 0.0010
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6981 - loss: 1.0254 - val_accuracy: 0.7295 - val_loss: 1.0665 - learning_rate: 0.0010
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7380 - loss: 0.8246 - val_accuracy: 0.8221 - val_loss: 0.7017 - learning_rate: 0.0010
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7436 - loss: 0.7171 - val_accuracy: 0.7722 - val_loss: 0.9516 - learning_rate: 0.0010
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7715 - loss: 0.7446 - val_accuracy: 0.6726 - val_loss: 1.9485 - learning_rate: 0.0010
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7804 - loss: 0.7974 - val_accuracy: 0.8665 - val_loss: 0.6080 - learning_rate: 5.0000e-04
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8169 - loss: 0.5281 - val_accuracy: 0.8665 - val_loss: 0.5215 - learning_rate: 5.0000e-04
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7932 - loss: 0.6030 - val_accuracy: 0.8452 - val_loss: 0.6882 - learning_rate: 5.0000e-04
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8323 - loss: 0.5213 - val_accuracy: 0.8790 - val_loss: 0.5817 - learning_rate: 5.0000e-04
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8179 - loss: 0.5705 - val_accuracy: 0.8968 - val_loss: 0.4387 - learning_rate: 5.0000e-04
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8244 - loss: 0.4467 - val_accuracy: 0.8950 - val_loss: 0.4234 - learning_rate: 5.0000e-04
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8436 - loss: 0.3974 - val_accuracy: 0.9057 - val_loss: 0.4273 - learning_rate: 5.0000e-04
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8706 - loss: 0.3767 - val_accuracy: 0.8826 - val_loss: 0.4730 - learning_rate: 5.0000e-04
# Fold 2 validation accuracy: 88.26%
# Fold 3/5
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2783 - loss: 12.6338 - val_accuracy: 0.2954 - val_loss: 3.9676 - learning_rate: 0.0010
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5529 - loss: 2.5669 - val_accuracy: 0.5943 - val_loss: 1.5004 - learning_rate: 0.0010
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6123 - loss: 1.2769 - val_accuracy: 0.7100 - val_loss: 1.1171 - learning_rate: 0.0010
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6662 - loss: 1.0152 - val_accuracy: 0.7598 - val_loss: 0.9325 - learning_rate: 0.0010
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6563 - loss: 1.1195 - val_accuracy: 0.6833 - val_loss: 1.1134 - learning_rate: 0.0010
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6748 - loss: 1.0337 - val_accuracy: 0.7331 - val_loss: 1.0160 - learning_rate: 0.0010
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7044 - loss: 0.9625 - val_accuracy: 0.7776 - val_loss: 0.9273 - learning_rate: 0.0010
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7073 - loss: 0.8089 - val_accuracy: 0.7633 - val_loss: 0.9027 - learning_rate: 0.0010
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7027 - loss: 0.8887 - val_accuracy: 0.8096 - val_loss: 0.8671 - learning_rate: 0.0010
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7444 - loss: 0.8626 - val_accuracy: 0.7562 - val_loss: 0.9208 - learning_rate: 0.0010
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7501 - loss: 0.8320 - val_accuracy: 0.7794 - val_loss: 0.9175 - learning_rate: 0.0010
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7593 - loss: 0.7893 - val_accuracy: 0.8416 - val_loss: 0.6731 - learning_rate: 0.0010
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7374 - loss: 0.8028 - val_accuracy: 0.7972 - val_loss: 1.0540 - learning_rate: 0.0010
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7259 - loss: 0.8851 - val_accuracy: 0.7687 - val_loss: 0.9091 - learning_rate: 0.0010
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7926 - loss: 0.6000 - val_accuracy: 0.7651 - val_loss: 1.1652 - learning_rate: 0.0010
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7516 - loss: 0.7865 - val_accuracy: 0.6548 - val_loss: 2.7170 - learning_rate: 0.0010
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7469 - loss: 0.7851 - val_accuracy: 0.7509 - val_loss: 1.3766 - learning_rate: 0.0010
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7623 - loss: 0.8037 - val_accuracy: 0.8701 - val_loss: 0.5834 - learning_rate: 5.0000e-04
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7959 - loss: 0.5775 - val_accuracy: 0.8043 - val_loss: 0.7723 - learning_rate: 5.0000e-04
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8065 - loss: 0.6133 - val_accuracy: 0.9057 - val_loss: 0.4828 - learning_rate: 5.0000e-04
# Fold 3 validation accuracy: 90.57%
# Fold 4/5
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2628 - loss: 12.3292 - val_accuracy: 0.3351 - val_loss: 3.6914 - learning_rate: 0.0010
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5074 - loss: 2.5558 - val_accuracy: 0.6649 - val_loss: 1.6415 - learning_rate: 0.0010
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5883 - loss: 1.3205 - val_accuracy: 0.5989 - val_loss: 2.5940 - learning_rate: 0.0010
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6023 - loss: 1.1798 - val_accuracy: 0.6934 - val_loss: 1.0322 - learning_rate: 0.0010
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6927 - loss: 0.8830 - val_accuracy: 0.7665 - val_loss: 0.9269 - learning_rate: 0.0010
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6700 - loss: 0.9705 - val_accuracy: 0.6881 - val_loss: 1.0331 - learning_rate: 0.0010
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6979 - loss: 0.8330 - val_accuracy: 0.7308 - val_loss: 0.9183 - learning_rate: 0.0010
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7102 - loss: 0.8324 - val_accuracy: 0.8182 - val_loss: 0.8423 - learning_rate: 0.0010
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7358 - loss: 0.7490 - val_accuracy: 0.7219 - val_loss: 0.9220 - learning_rate: 0.0010
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7081 - loss: 0.8834 - val_accuracy: 0.8556 - val_loss: 0.7539 - learning_rate: 0.0010
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7015 - loss: 0.8780 - val_accuracy: 0.8663 - val_loss: 0.5875 - learning_rate: 0.0010
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7269 - loss: 0.8194 - val_accuracy: 0.7807 - val_loss: 0.9640 - learning_rate: 0.0010
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7414 - loss: 0.7594 - val_accuracy: 0.8182 - val_loss: 0.8319 - learning_rate: 0.0010
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7421 - loss: 0.7460 - val_accuracy: 0.7504 - val_loss: 1.3687 - learning_rate: 0.0010
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7456 - loss: 0.8739 - val_accuracy: 0.8271 - val_loss: 0.7537 - learning_rate: 0.0010
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7453 - loss: 0.7429 - val_accuracy: 0.8182 - val_loss: 0.8558 - learning_rate: 0.0010
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7602 - loss: 0.7852 - val_accuracy: 0.8414 - val_loss: 0.6518 - learning_rate: 5.0000e-04
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8287 - loss: 0.4752 - val_accuracy: 0.8966 - val_loss: 0.4494 - learning_rate: 5.0000e-04
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8301 - loss: 0.5298 - val_accuracy: 0.8859 - val_loss: 0.4847 - learning_rate: 5.0000e-04
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8406 - loss: 0.4338 - val_accuracy: 0.8734 - val_loss: 0.4927 - learning_rate: 5.0000e-04
# Fold 4 validation accuracy: 87.34%
# Fold 5/5
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2732 - loss: 12.6290 - val_accuracy: 0.3155 - val_loss: 4.2944 - learning_rate: 0.0010
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5341 - loss: 3.1050 - val_accuracy: 0.6471 - val_loss: 1.7751 - learning_rate: 0.0010
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6418 - loss: 1.4641 - val_accuracy: 0.7932 - val_loss: 0.9757 - learning_rate: 0.0010
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6829 - loss: 0.9377 - val_accuracy: 0.7005 - val_loss: 1.1005 - learning_rate: 0.0010
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6844 - loss: 0.9864 - val_accuracy: 0.7861 - val_loss: 1.0258 - learning_rate: 0.0010
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7083 - loss: 0.9375 - val_accuracy: 0.8253 - val_loss: 0.8247 - learning_rate: 0.0010
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7136 - loss: 0.8889 - val_accuracy: 0.8200 - val_loss: 0.7466 - learning_rate: 0.0010
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7428 - loss: 0.7072 - val_accuracy: 0.7914 - val_loss: 0.8019 - learning_rate: 0.0010
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7575 - loss: 0.7381 - val_accuracy: 0.8093 - val_loss: 0.7374 - learning_rate: 0.0010
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7524 - loss: 0.7552 - val_accuracy: 0.8503 - val_loss: 0.6298 - learning_rate: 0.0010
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7642 - loss: 0.8314 - val_accuracy: 0.8378 - val_loss: 0.7743 - learning_rate: 0.0010
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7635 - loss: 0.7557 - val_accuracy: 0.7914 - val_loss: 0.9437 - learning_rate: 0.0010
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7072 - loss: 1.1393 - val_accuracy: 0.7968 - val_loss: 0.8952 - learning_rate: 0.0010
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7840 - loss: 0.6590 - val_accuracy: 0.8021 - val_loss: 0.8006 - learning_rate: 0.0010
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7944 - loss: 0.6252 - val_accuracy: 0.8788 - val_loss: 0.5953 - learning_rate: 0.0010
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7888 - loss: 0.6924 - val_accuracy: 0.8128 - val_loss: 0.8646 - learning_rate: 0.0010
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7891 - loss: 0.6856 - val_accuracy: 0.7968 - val_loss: 0.7683 - learning_rate: 0.0010
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7695 - loss: 0.6797 - val_accuracy: 0.8503 - val_loss: 0.8840 - learning_rate: 0.0010
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7964 - loss: 0.7044 - val_accuracy: 0.8824 - val_loss: 0.7057 - learning_rate: 0.0010
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7604 - loss: 0.9434 - val_accuracy: 0.6791 - val_loss: 1.2925 - learning_rate: 0.0010
# Fold 5 validation accuracy: 67.91%
# 평균 검증 정확도: 84.50%
# 최종 모델이 'final_model_1120.keras'로 저장되었습니다.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# 모델 예측 값
y_prob = model.predict(X_val_fold)  # X_val_fold: 검증 데이터

# 실제 클래스 레이블
y_true = y_val_fold  # 실제 클래스 레이블

# 클래스 수
n_classes = 18  # 18개의 클래스

# 이진화된 클래스 레이블
y_true_bin = label_binarize(y_true, classes=np.arange(n_classes))

# ROC 곡선 계산
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ROC 곡선 시각화
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# 대각선 랜덤 분류선
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

# 설정
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (Multi-class)')
plt.legend(loc="lower right")

# 그래프 표시
plt.show()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/hongrae/Downloads/Hallym_project/venv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1183: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
import tensorflow as tf

print("TensorFlow 버전:", tf.__version__)
print("GPU 사용 가능 여부:", len(tf.config.list_physical_devices('GPU')) > 0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       3 print("TensorFlow 버전:", tf.__version__)
#       4 print("GPU 사용 가능 여부:", len(tf.config.list_physical_devices('GPU')) > 0)
#
# ModuleNotFoundError: No module named 'tensorflow'
